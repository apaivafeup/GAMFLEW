# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

yint = range(0, 5)

# %%
df = pandas.read_csv('q2.csv')

df['GAMFLEW gives error messages that clearly tell me how to correct the problems.'].value_counts().plot(kind='bar', xlabel='', ylabel='frequency')
# Out:
# <Axes: ylabel='frequency'>
