# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot, plot

# %%
q2 = pd.read_csv('q2.csv')

# %%
column_names = ['date', 'code']
for i in range(1, 44):
    column_names.append(str(i))

# %%
q2.columns = column_names

# %%
strongly_agree = []
agree = []
neutral = []
disagree = []
strongly_disagree = []

for i in range(1, 43):
    # check if there is a value in the column
    if 'Strongly agree' in q2[str(i)].value_counts().index:
        strongly_agree.append(q2[str(i)].value_counts()['Strongly agree'])
    else:
        strongly_agree.append(0)

    if 'Agree' in q2[str(i)].value_counts().index:
        agree.append(q2[str(i)].value_counts()['Agree'])
    else:
        agree.append(0)

    if 'Neutral' in q2[str(i)].value_counts().index:
        neutral.append(q2[str(i)].value_counts()['Neutral'])
    else:
        neutral.append(0)

    if 'Disagree' in q2[str(i)].value_counts().index:
        disagree.append(q2[str(i)].value_counts()['Disagree'])
    else:
        disagree.append(0)

    if 'Strongly disagree' in q2[str(i)].value_counts().index:
        strongly_disagree.append(q2[str(i)].value_counts()['Strongly disagree'])
    else:
        strongly_disagree.append(0)

# %%
# 0 to 10 
strongly_agree_10 = strongly_agree[:10]
agree_10 = agree[:10]
neutral_10 = neutral[:10]
disagree_10 = disagree[:10]
strongly_disagree_10 = strongly_disagree[:10]

data = pd.DataFrame({
    "Strongly agree": strongly_agree_10,
    "Agree": agree_10,
    "Neutral": neutral_10,
    "Disagree": disagree_10,
    "Strongly disagree": strongly_disagree_10},
    index = [str(i) for i in range(1, 11)]
)

data.plot(kind="bar",figsize=(15, 8))

plt.title("Questionnaire 2 Answers (1-10)")

plt.xlabel("Questions")

plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# 10 to 20 
strongly_agree_20 = strongly_agree[10:20]
agree_20 = agree[10:20]
neutral_20 = neutral[10:20]
disagree_20 = disagree[10:20]
strongly_disagree_20 = strongly_disagree[10:20]

data = pd.DataFrame({
    "Strongly agree": strongly_agree_20,
    "Agree": agree_20,
    "Neutral": neutral_20,
    "Disagree": disagree_20,
    "Strongly disagree": strongly_disagree_20},
    index = [str(i) for i in range(11, 21)]
)

data.plot(kind="bar",figsize=(15, 8))

plt.title("Questionnaire 2 Answers (11-20)")

plt.xlabel("Questions")

plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# 20 to 30 
strongly_agree_30 = strongly_agree[20:30]
agree_30 = agree[20:30]
neutral_30 = neutral[20:30]
disagree_30 = disagree[20:30]
strongly_disagree_30 = strongly_disagree[20:30]

data = pd.DataFrame({
    "Strongly agree": strongly_agree_30,
    "Agree": agree_30,
    "Neutral": neutral_30,
    "Disagree": disagree_30,
    "Strongly disagree": strongly_disagree_30},
    index = [str(i) for i in range(21, 31)]
)

data.plot(kind="bar",figsize=(15, 8))

plt.title("Questionnaire 2 Answers (21-30)")

plt.xlabel("Questions")

plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# 30 to 40 
strongly_agree_40 = strongly_agree[30:40]
agree_40 = agree[30:40]
neutral_40 = neutral[30:40]
disagree_40 = disagree[30:40]
strongly_disagree_40 = strongly_disagree[30:40]

data = pd.DataFrame({
    "Strongly agree": strongly_agree_40,
    "Agree": agree_40,
    "Neutral": neutral_40,
    "Disagree": disagree_40,
    "Strongly disagree": strongly_disagree_40},
    index = [str(i) for i in range(31, 41)]
)

data.plot(kind="bar",figsize=(15, 8))

plt.title("Questionnaire 2 Answers (31-40)")

plt.xlabel("Questions")

plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
strongly_agree_last = strongly_agree[40:]
agree_last = agree[40:]
neutral_last = neutral[40:]
disagree_last = disagree[40:]
strongly_disagree_last = strongly_disagree[40]

data = pd.DataFrame({
    "Strongly agree": strongly_agree_last,
    "Agree": agree_last,
    "Neutral": neutral_last,
    "Disagree": disagree_last,
    "Strongly disagree": strongly_disagree_last},
    index = [str(i) for i in range(41, 43)]
)

data.plot(kind="bar",figsize=(15, 8))

plt.title("Questionnaire 2 Answers (41-42)")

plt.xlabel("Questions")

plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
